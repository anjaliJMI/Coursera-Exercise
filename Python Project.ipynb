# %%
pip install yfinance
# Out:
# ...
#
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/09/82/5a5eee685095a6c1f8968db75bba8536baa8046c970be25e1ac91a843839/yfinance-0.2.33-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for frozendict>=2.3.4 from https://files.pythonhosted.org/packages/b6/2c/e391d6d57bbd837d383a6b69b54ecb4768d75b31d8bc7a380b4b4afe4cb2/frozendict-2.3.10-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/2.9 MB 5.2 MB/s eta 0:00:01
#      ------ --------------------------------- 0.5/2.9 MB 6.2 MB/s eta 0:00:01
#      ---------- ----------------------------- 0.7/2.9 MB 5.9 MB/s eta 0:00:01
#      ------------- -------------------------- 1.0/2.9 MB 6.2 MB/s eta 0:00:01
#      ------------------- -------------------- 1.5/2.9 MB 6.6 MB/s eta 0:00:01
#      ----------------------- ---------------- 1.8/2.9 MB 6.6 MB/s eta 0:00:01
# ...

# %% [markdown]
# # Question 1 - Extracting Tesla Stock Data Using yfinance

# %%
import yfinance as yf

# Specify the stock symbol and the date range
stock_symbol = "TSLA"
start_date = "2022-01-01"
end_date = "2023-01-01"

# Download the stock data
tesla_data = yf.download(stock_symbol, start=start_date, end=end_date)

# Display the first few rows of the data
print(tesla_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  382.583344  400.356659  378.679993  399.926666  399.926666
# 2022-01-04  396.516663  402.666656  374.350006  383.196655  383.196655
# 2022-01-05  382.216675  390.113342  360.336670  362.706665  362.706665
# 2022-01-06  359.000000  362.666656  340.166656  354.899994  354.899994
# 2022-01-07  360.123322  360.309998  336.666656  342.320007  342.320007
#
#                Volume
# Date
# 2022-01-03  103931400
# 2022-01-04  100248300
# 2022-01-05   80119800
# 2022-01-06   90336600
# 2022-01-07   84164700

# %% [markdown]
# # Question 2 - Extracting Tesla Revenue Data Using Webscraping

# %%
# Question 2 - Extracting Tesla Revenue Data Using Webscraping - 2 Points

# Import necessary libraries for webscraping
import requests
from bs4 import BeautifulSoup

tesla_revenue_url = "https://ir.tesla.com/#quarterly-disclosure" 

# Send a GET request to the URL
response = requests.get(tesla_revenue_url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Add code for extracting revenue data from the HTML soup
    # Adjust this section based on the actual structure of the webpage
    
    # Example: Find and print the title of the webpage
    title = soup.title
    print("Webpage Title:", title.text)

else:
    print("Failed to retrieve data. Check the URL or try again later.")
# Out:
# Webpage Title: Investor Relations | Tesla Investor Relations

# %% [markdown]
# # Question 3 - Extracting GameStop Stock Data Using yfinance

# %%
# Importing necessary libraries for fetching GameStop stock data
import yfinance as yf

# Specify the stock symbol and the date range
stock_symbol = "GME"
start_date = "2022-01-01"
end_date = "2023-01-01"

# Download the stock data
gamestop_data = yf.download(stock_symbol, start=start_date, end=end_date)

# Display the first few rows of the data
print(gamestop_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2022-01-03  37.307499  39.845001  37.302502  38.209999  38.209999   5654800
# 2022-01-04  38.042500  38.247501  35.762501  37.227501  37.227501   7339600
# 2022-01-05  37.097500  37.212502  32.287498  32.342499  32.342499  13585600
# 2022-01-06  33.209999  34.424999  30.285000  32.757500  32.757500  24206000
# 2022-01-07  39.942501  40.077499  33.125000  35.154999  35.154999  48549200

# %% [markdown]
# # Question 4 - Extracting GameStop Revenue Data Using Webscraping

# %%
# Question 4 - Extracting GameStop Revenue Data Using Webscraping - 2 Points

# Import necessary libraries for webscraping
import requests
from bs4 import BeautifulSoup

# URL for GameStop's revenue data (Replace with the actual URL)
gamestop_revenue_url = "https://ir.tesla.com/#quarterly-disclosure" 

# Send a GET request to the URL
response = requests.get(gamestop_revenue_url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')


    title = soup.title
    print("Webpage Title:", title.text)

else:
    print("Failed to retrieve data. Check the URL or try again later.")
# Out:
# Webpage Title: Investor Relations | Tesla Investor Relations

# %% [markdown]
# # Question 5 - Tesla Stock and Revenue Dashboard

# %%
# Import necessary libraries for data analysis and visualization
import yfinance as yf
import matplotlib.pyplot as plt
import plotly.express as px

# Function to fetch stock data
def fetch_stock_data(symbol, start_date, end_date):
    stock_data = yf.download(symbol, start=start_date, end=end_date)
    return stock_data

# Function to fetch revenue data (Placeholder URL, replace with actual URL and code)
def fetch_revenue_data():
    # Implement web scraping or use API to fetch revenue data
    # Add your code here
    pass

# Main function to create the dashboard
def create_dashboard():
    # Fetch Tesla stock data
    tesla_stock_data = fetch_stock_data("TSLA", "2022-01-01", "2023-01-01")

    # Fetch Tesla revenue data (Placeholder, replace with actual function call)
    tesla_revenue_data = fetch_revenue_data()

    # Create a simple line plot for stock data using matplotlib
    plt.figure(figsize=(10, 5))
    plt.plot(tesla_stock_data['Close'], label='Tesla Stock Close Price')
    plt.title('Tesla Stock Close Price Over Time')
    plt.xlabel('Date')
    plt.ylabel('Stock Close Price (USD)')
    plt.legend()
    plt.show()

    # Create an interactive line plot for revenue data using plotly
    fig = px.line(x=tesla_revenue_data.index, y=tesla_revenue_data['Revenue'], title='Tesla Revenue Over Time')
    fig.update_layout(xaxis_title='Date', yaxis_title='Revenue (Millions USD)')
    fig.show()

# Execute the main function to create the dashboard
create_dashboard()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 40
#      37     fig.show()
#      39 # Execute the main function to create the dashboard
# ---> 40 create_dashboard()
#
# Cell In[18], line 35, in create_dashboard()
#      32 plt.show()
#      34 # Create an interactive line plot for revenue data using plotly
# ---> 35 fig = px.line(x=tesla_revenue_data.index, y=tesla_revenue_data['Revenue'], title='Tesla Revenue Over Time')
#      36 fig.update_layout(xaxis_title='Date', yaxis_title='Revenue (Millions USD)')
#      37 fig.show()
#
# AttributeError: 'NoneType' object has no attribute 'index'

# %% [markdown]
# # Question 6 - GameStop Stock and Revenue Dashboard

# %%
# Import necessary libraries for data analysis and visualization
import yfinance as yf
import matplotlib.pyplot as plt
import plotly.express as px

# Function to fetch stock data
def fetch_stock_data(symbol, start_date, end_date):
    stock_data = yf.download(symbol, start=start_date, end=end_date)
    return stock_data

# Function to fetch revenue data (Placeholder URL, replace with actual URL and code)
def fetch_revenue_data():
    # Implement web scraping or use API to fetch revenue data
    # Add your code here
    pass

# Main function to create the dashboard
def create_dashboard():
    # Fetch GameStop stock data
    gamestop_stock_data = fetch_stock_data("GME", "2022-01-01", "2023-01-01")

    # Fetch GameStop revenue data (Placeholder, replace with actual function call)
    gamestop_revenue_data = fetch_revenue_data()

    # Create a simple line plot for stock data using matplotlib
    plt.figure(figsize=(10, 5))
    plt.plot(gamestop_stock_data['Close'], label='GameStop Stock Close Price')
    plt.title('GameStop Stock Close Price Over Time')
    plt.xlabel('Date')
    plt.ylabel('Stock Close Price (USD)')
    plt.legend()
    plt.show()

    # Create an interactive line plot for revenue data using plotly
    fig = px.line(x=gamestop_revenue_data.index, y=gamestop_revenue_data['Revenue'], title='GameStop Revenue Over Time')
    fig.update_layout(xaxis_title='Date', yaxis_title='Revenue (Millions USD)')
    fig.show()

# Execute the main function to create the dashboard
create_dashboard()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 40
#      37     fig.show()
#      39 # Execute the main function to create the dashboard
# ---> 40 create_dashboard()
#
# Cell In[19], line 35, in create_dashboard()
#      32 plt.show()
#      34 # Create an interactive line plot for revenue data using plotly
# ---> 35 fig = px.line(x=gamestop_revenue_data.index, y=gamestop_revenue_data['Revenue'], title='GameStop Revenue Over Time')
#      36 fig.update_layout(xaxis_title='Date', yaxis_title='Revenue (Millions USD)')
#      37 fig.show()
#
# AttributeError: 'NoneType' object has no attribute 'index'
